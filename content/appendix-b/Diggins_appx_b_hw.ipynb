# %% [markdown]
# # 95% - good job, lacks problem statements, TEO

# %%
#Diggins_appx_b_hw
#this file was developed to complete the two excercises in Appx B

# %%
import numpy
import matplotlib

# %%
# %run PSP_numericalDerivation

"""
'numerical Derivation' calls in the PSP_read data and then inports a function within that code.
then it imports matplotlib

in the first loop a derivative is established for each point along the line but I am not exactly sure how this gets determined

"""
# Out:
# ['#Hour ', 'Temp(C)']
# ['1', '12.48893452']
# ['2', '9.769722939']
# ['3', '11.34481716']
# ['4', '11.65844917']
# ['5', '14.50185585']
# ['6', '16.84011841']
# ['7', '20.63397789']
# ['8', '24.01938057']
# ['9', '27.98606491']
# ['10', '31.33218765']
# ['11', '34.55152512']
# ['12', '36.87175751']
# ['13', '38.56958389']
# ['14', '39.193367']
# ['15', '38.96338272']
# ['16', '37.68754959']
# ['17', '35.61053467']
# ['18', '32.7460556']
# ['19', '29.38426208']
# ['20', '25.67911339']
# ['21', '21.94166374']
# ['22', '18.38553429']
# ['23', '15.28931332']
# ['24', '12.84177303']
# "\n'numerical Derivation' calls in the PSP_read data and then inports a function within that code.\nthen it imports matplotlib\n\nin the first loop a derivative is established for each point along the line but I am not exactly sure how this gets determined\n\n"

# %%
import PSP_Simpson
#(x(sin(x)*np.exp(-x*0.5))
#print(PSP_Simpson.x(sin(x)*np.exp(-x*0.5)))

# %%
def func(x):
    return sin(x)*np.exp(-x*0.5);

# %%
integral = qsimp(func, 1,4);
print ("Numerical solution:")
print (integral)
# Out:
# Numerical solution:
# 0.5780567596921441
