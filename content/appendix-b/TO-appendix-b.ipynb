# %%
import numpy as np
import matplotlib as plt

# %%
from PSP_Simpson import qsimp

# %%
def func(x):
	return (x);

# %%
integral = qsimp(func,1,4);
print ("Numerical solution:")
print (integral)
# Out:
# Numerical solution:
# 7.5
