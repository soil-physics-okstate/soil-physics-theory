# %%
import numpy
import matplotlib

# %%
run PSP_numericalDerivation
# Out:
# ['#Hour ', 'Temp(C)']
# ['1', '12.48893452']
# ['2', '9.769722939']
# ['3', '11.34481716']
# ['4', '11.65844917']
# ['5', '14.50185585']
# ['6', '16.84011841']
# ['7', '20.63397789']
# ['8', '24.01938057']
# ['9', '27.98606491']
# ['10', '31.33218765']
# ['11', '34.55152512']
# ['12', '36.87175751']
# ['13', '38.56958389']
# ['14', '39.193367']
# ['15', '38.96338272']
# ['16', '37.68754959']
# ['17', '35.61053467']
# ['18', '32.7460556']
# ['19', '29.38426208']
# ['20', '25.67911339']
# ['21', '21.94166374']
# ['22', '18.38553429']
# ['23', '15.28931332']
# ['24', '12.84177303']

# %%
run PSP_Simpson.py
# Out:
# Numerical solution:
# 1.386294371125764
