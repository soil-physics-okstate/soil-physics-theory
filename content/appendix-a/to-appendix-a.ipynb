# %%
# to-appendix-a.ipynb
# Pip is a package-management system written in Python that is used to install and manage software packages. 
# Micropip is a version of the Pip Python package manager that works with Pyodide. 
# Piplite is a wrapper around micropip in JupyterLite.
import piplite
await piplite.install("matplotlib")

# %%
run PSP_averageTair.py # Compute and plot hourly average air temperature based on 10-minute data

# %%
run PSP_soilTemp.py # Plot soil temperatures at 70 and 135 cm depths
# Out:
# first date: 2007-07-15 06:00:00
# last date:  2009-02-25 16:00:00
