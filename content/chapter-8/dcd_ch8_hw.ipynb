# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
# %cd drive
# %cd MyDrive
# %cd GitHub
# %cd soil-physics-theory
# %cd content
# %cd chapter-8
# Out:
# /content/drive
# /content/drive/MyDrive
# /content/drive/MyDrive/GitHub
# /content/drive/MyDrive/GitHub/soil-physics-theory
# /content/drive/MyDrive/GitHub/soil-physics-theory/content
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-8

# %%
import matplotlib.pyplot as plt
import PSP_infiltration1D as inf
import numpy as np
from main_cole import main

# %% [markdown]
# **8.1. Use the program PSP_infiltrationRedistribution1D with different hydraulic property functions and numerical schemes. Investigate the effect on the cumulative infiltration and on the total number of iterations.**

# %%
main(1,2,.3,1,48)
# Out:
# 1  Campbell
# 2  van Genuchten with m = 1-1/n restriction
# 3  Ippisch-van Genuchten
#
# 1  Cell-Centered Finite Volume
# 2  Matric Potential with Newton-Raphson
# 3  Matric Flux Potential with Newton-Raphson
#
#
# 1: Free drainage
# 2: Constant water potential
# dt = 360.0 No convergence
# dt = 180.0 No convergence
# dt = 90.0 No convergence
# dt = 45.0 No convergence
# dt = 22.5 No convergence
# dt = 11.25 No convergence
# dt = 5.625 No convergence
# dt = 2.8125 No convergence
# dt = 1.40625 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# dt = 1 No convergence
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-fdf24c2401c4> in <cell line: 1>()
# ----> 1 main(1,2,.3,1,48)
#
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-8/main_cole.py in main(funcType, solver, Se, boundary, simulationLength)
#      74                         soil, dt, ubPotential, isFreeDrainage,inf.LOGARITHMIC)
#      75         elif (solver == inf.NEWTON_RAPHSON_MP):
# ---> 76             success, nrIterations, flux = inf.NewtonRapsonMP(funcType,
#      77                         soil, dt, ubPotential, isFreeDrainage)
#      78         elif (solver == inf.NEWTON_RAPHSON_MFP):
#
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-8/PSP_infiltration1D.py in NewtonRapsonMP(funcType, soil, dt, ubPotential, isFreeDrainage)
#      83             u[i] = g * k[i]
#      84             du[i] = -u[i] * soil[hor[i]].Campbell_n / psi[i]
# ---> 85             capacity = dTheta_dPsi(funcType, soil[hor[i]], psi[i])
#      86             C[i] = (waterDensity * vol[i] * capacity) / dt
#      87
#
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-8/PSP_soil.py in dTheta_dPsi(funcType, soil, psi)
#     159 # dTheta/dH = dSe/dH (Theta_s - Theta_r)
#     160 #---------------------------------------------
# --> 161 def dTheta_dPsi(funcType, soil, psi):
#     162     airEntry = airEntryPotential(funcType, soil)
#     163     if (psi > airEntry): return 0.0
#
# KeyboardInterrupt:

# %% [markdown]
# **8.2. Using the program PSP_infiltrationRedistribution1D, select a hy- draulic property function and a numerical scheme. Using the same settings, change the value of the soil initial water content and investigate the effect on the cumulative infiltration. How do the profiles of soil water content differ?**

# %% [markdown]
# **8.3.Using the program PSP_infiltrationRedistribution1D, select a hy- draulic property function and a numerical scheme. Using the same settings, change the value of the lower boundary condition and investigate the effect on the total cumulative infiltration.**

# %% [markdown]
# **8.4. Modify the program such that there are two layers: 0.5 m of sandy soil at the top and clay soil at the bottom. What do you expect for the infiltration process. Run the program and compare the results.**

# %% [markdown]
# **8.5. previous with inverted layers**
