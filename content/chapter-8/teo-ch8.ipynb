# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/Github
# %cd 'soil-physics-theory'
# %cd 'content/chapter-8'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Github
# /content/drive/MyDrive/Github/soil-physics-theory
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8

# %% [markdown]
# **8.1. Use the program PSP_infiltrationRedistribution1D with different hydraulic property functions and numerical schemes. Investigate the effect on the cumulative infiltration and on the total number of iterations.**

# %%
import pdb

# %%
Ratrun main.py
# Out:
# 1  Campbell
# 2  van Genuchten with m = 1-1/n restriction
# 3  Ippisch-van Genuchten
# Select water retention curve: 1
#
# 1  Cell-Centered Finite Volume
# 2  Matric Potential with Newton-Raphson
# 3  Matric Flux Potential with Newton-Raphson
# Select solver: 1
#
# Initial degree of saturation ]0-1]:0.1
#
# 1: Free drainage
# 2: Constant water potential
# Select lower boundary condition:1
#
# Nr of simulation hours:6
# dt = 360.0 No convergence
# dt = 180.0 No convergence
# dt = 90.0 No convergence
# dt = 45.0 No convergence
# dt = 22.5 No convergence
# dt = 11.25 No convergence
# dt = 5.625 No convergence
# dt = 2.8125 No convergence
# dt = 1.40625 No convergence
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/lib/python3.10/bdb.py", line 336, in set_trace
#     sys.settrace(self.trace_dispatch)
# nr of iterations per hour: 1109.0
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(120)main()
#     118     print("nr of iterations per hour:", totalIterationNr / simulationLenght)
#     119     breakpoint()
# --> 120     f, myPlot = plt.subplots(2, figsize=(10, 8), dpi=80)
#     121     myPlot[1].set_xlim(0, simulationLenght * 3600)
#     122     myPlot[1].set_ylim(0, 0.1)
#
# ipdb> n
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(121)main()
#     119     breakpoint()
#     120     f, myPlot = plt.subplots(2, figsize=(10, 8), dpi=80)
# --> 121     myPlot[1].set_xlim(0, simulationLenght * 3600)
#     122     myPlot[1].set_ylim(0, 0.1)
#     123     myPlot[1].set_xlabel("Time [s]",fontsize=16,labelpad=8)
#
# ipdb> n
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(122)main()
#     120     f, myPlot = plt.subplots(2, figsize=(10, 8), dpi=80)
#     121     myPlot[1].set_xlim(0, simulationLenght * 3600)
# --> 122     myPlot[1].set_ylim(0, 0.1)
#     123     myPlot[1].set_xlabel("Time [s]",fontsize=16,labelpad=8)
#     124     myPlot[1].set_ylabel("Infiltration Rate [kg m$^{-2}$ s$^{-1}$]",fontsize=16,labelpad=8)
#
# ipdb> n
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(123)main()
#     121     myPlot[1].set_xlim(0, simulationLenght * 3600)
#     122     myPlot[1].set_ylim(0, 0.1)
# --> 123     myPlot[1].set_xlabel("Time [s]",fontsize=16,labelpad=8)
#     124     myPlot[1].set_ylabel("Infiltration Rate [kg m$^{-2}$ s$^{-1}$]",fontsize=16,labelpad=8)
#     125     plt.tick_params(axis='both', which='major', labelsize=12,pad=6)
#
# ipdb> n
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(124)main()
#     122     myPlot[1].set_ylim(0, 0.1)
#     123     myPlot[1].set_xlabel("Time [s]",fontsize=16,labelpad=8)
# --> 124     myPlot[1].set_ylabel("Infiltration Rate [kg m$^{-2}$ s$^{-1}$]",fontsize=16,labelpad=8)
#     125     plt.tick_params(axis='both', which='major', labelsize=12,pad=6)
#     126     myPlot[0].clear()
#
# ipdb> n
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(125)main()
#     123     myPlot[1].set_xlabel("Time [s]",fontsize=16,labelpad=8)
#     124     myPlot[1].set_ylabel("Infiltration Rate [kg m$^{-2}$ s$^{-1}$]",fontsize=16,labelpad=8)
# --> 125     plt.tick_params(axis='both', which='major', labelsize=12,pad=6)
#     126     myPlot[0].clear()
#     127     myPlot[0].set_xlim(0, 0.5)
#
# ipdb> n
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(126)main()
#     124     myPlot[1].set_ylabel("Infiltration Rate [kg m$^{-2}$ s$^{-1}$]",fontsize=16,labelpad=8)
#     125     plt.tick_params(axis='both', which='major', labelsize=12,pad=6)
# --> 126     myPlot[0].clear()
#     127     myPlot[0].set_xlim(0, 0.5)
#     128     myPlot[0].set_xlabel("Water content [m$^3$ m$^{-3}$]",fontsize=16,labelpad=8)
#
# ipdb> n
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(127)main()
#     125     plt.tick_params(axis='both', which='major', labelsize=12,pad=6)
#     126     myPlot[0].clear()
# --> 127     myPlot[0].set_xlim(0, 0.5)
#     128     myPlot[0].set_xlabel("Water content [m$^3$ m$^{-3}$]",fontsize=16,labelpad=8)
#     129     myPlot[0].set_ylabel("Depth [m]",fontsize=16,labelpad=8)
#
# ipdb> n
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(128)main()
#     126     myPlot[0].clear()
#     127     myPlot[0].set_xlim(0, 0.5)
# --> 128     myPlot[0].set_xlabel("Water content [m$^3$ m$^{-3}$]",fontsize=16,labelpad=8)
#     129     myPlot[0].set_ylabel("Depth [m]",fontsize=16,labelpad=8)
#     130     myPlot[0].plot(inf.theta, -inf.z, 'k-')
#
# ipdb> n
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(129)main()
#     127     myPlot[0].set_xlim(0, 0.5)
#     128     myPlot[0].set_xlabel("Water content [m$^3$ m$^{-3}$]",fontsize=16,labelpad=8)
# --> 129     myPlot[0].set_ylabel("Depth [m]",fontsize=16,labelpad=8)
#     130     myPlot[0].plot(inf.theta, -inf.z, 'k-')
#     131     myPlot[0].plot(inf.theta, -inf.z, 'ko')
#
# ipdb> inf.theta.shape
# (52,)
# ipdb> inf.z.shape
# (52,)
# ipdb> n
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(130)main()
#     128     myPlot[0].set_xlabel("Water content [m$^3$ m$^{-3}$]",fontsize=16,labelpad=8)
#     129     myPlot[0].set_ylabel("Depth [m]",fontsize=16,labelpad=8)
# --> 130     myPlot[0].plot(inf.theta, -inf.z, 'k-')
#     131     myPlot[0].plot(inf.theta, -inf.z, 'ko')
#     132     myPlot[0].draw(plt.gcf().canvas.get_renderer())
#
# ipdb> n
# > /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/main.py(131)main()
#     129     myPlot[0].set_ylabel("Depth [m]",fontsize=16,labelpad=8)
#     130     myPlot[0].plot(inf.theta, -inf.z, 'k-')
# --> 131     myPlot[0].plot(inf.theta, -inf.z, 'ko')
#     132     myPlot[0].draw(plt.gcf().canvas.get_renderer())
#     133     myPlot[1].plot(timeVec, infRate, 'ko')
#
# ipdb> timeVec.shape
# (52,)
# ipdb> infRate.shape
# (52,)
# ipdb> timeVec
# array([21587.8125, 21587.8125, 21587.8125, 21587.8125, 21587.8125,
#        21587.8125, 21587.8125, 21587.8125, 21587.8125, 21587.8125,
#        21587.8125, 21587.8125, 21587.8125, 21587.8125, 21587.8125,
#        21587.8125, 21587.8125, 21587.8125, 21587.8125, 21587.8125,
#        21587.8125, 21587.8125, 21587.8125, 21587.8125, 21587.8125,
#        21587.8125, 21587.8125, 21587.8125, 21587.8125, 21587.8125,
#        21587.8125, 21587.8125, 21587.8125, 21587.8125, 21587.8125,
#        21587.8125, 21587.8125, 21587.8125, 21587.8125, 21587.8125,
#        21587.8125, 21587.8125, 21587.8125, 21587.8125, 21587.8125,
#        21587.8125, 21587.8125, 21587.8125, 21587.8125, 21587.8125,
#        21587.8125, 21587.8125])
# ipdb> inf
# <module 'PSP_infiltration1D' from '/content/drive/MyDrive/Github/soil-physics-theory/content/chapter-8/PSP_infiltration1D.py'>
# ipdb> infRate
# array([0.00982101, 0.00982101, 0.00982101, 0.00982101, 0.00982101,
#        0.00982101, 0.00982101, 0.00982101, 0.00982101, 0.00982101,
#        0.00982101, 0.00982101, 0.00982101, 0.00982101, 0.00982101,
#        0.00982101, 0.00982101, 0.00982101, 0.00982101, 0.00982101,
#        0.00982101, 0.00982101, 0.00982101, 0.00982101, 0.00982101,
#        0.00982101, 0.00982101, 0.00982101, 0.00982101, 0.00982101,
#        0.00982101, 0.00982101, 0.00982101, 0.00982101, 0.00982101,
#        0.00982101, 0.00982101, 0.00982101, 0.00982101, 0.00982101,
#        0.00982101, 0.00982101, 0.00982101, 0.00982101, 0.00982101,
#        0.00982101, 0.00982101, 0.00982101, 0.00982101, 0.00982101,
#        0.00982101, 0.00982101])
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# **8.2. Using the program PSP_infiltrationRedistribution1D, select a hy- draulic property function and a numerical scheme. Using the same settings, change the value of the soil initial water content and investigate the effect on the cumulative infiltration. How do the profiles of soil water content differ?**

# %% [markdown]
# **8.3.Using the program PSP_infiltrationRedistribution1D, select a hy- draulic property function and a numerical scheme. Using the same settings, change the value of the lower boundary condition and investigate the effect on the total cumulative infiltration.**

# %% [markdown]
# **8.4. Modify the program such that there are two layers: 0.5 m of sandy soil at the top and clay soil at the bottom. What do you expect for the infiltration process. Run the program and compare the results.**

# %% [markdown]
# **8.5. RepeatExercise8.4,butinvertthetwolayers.**
