# %% [markdown]
# # 75% - missing problem statements, #1 incomplete, #2 inaccurate explanation, #4 no explanation, #5 missing

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/GitHub/
# %cd 'soil-physics-theory'
# %cd 'content/chapter-8'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/GitHub
# /content/drive/MyDrive/GitHub/soil-physics-theory
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-8

# %%
##Chapter_8.1

#With 0.55 m^3/m^3 as the initial soil water content, initial infiltration rate is relatively lower (~0.04 mm/s).
#The rate drops slowly through time until the soil becomes saturated (where infiltration rate is more or less constant)
#The soil water content doesn't change much with depth.
#It requires a total of 241.2 iterations per hour.

# %run main.py
# Out:
# 1  Campbell
# 2  van Genuchten with m = 1-1/n restriction
# 3  Ippisch-van Genuchten
# Select water retention curve: 1
#
# 1  Cell-Centered Finite Volume
# 2  Matric Potential with Newton-Raphson
# 3  Matric Flux Potential with Newton-Raphson
# Select solver: 1
#
# Initial degree of saturation ]0-1]:0.55
#
# 1: Free drainage
# 2: Constant water potential
# Select lower boundary condition:1
#
# Nr of simulation hours:5
# nr of iterations per hour: 241.2

# %%
##Chapter_8.2

#Under a relatively drier soil (with an initial soil water content of 0.25 0.55 m^3/m^3), the initial infiltration rate is relatively higher (~0.09 mm/s).
#The rate drops abruptly in the first few minutes until it reaches a constant rate, indicating a saturated soil condition.
#The wetting front is distinct.
#It requires a total of 872.8 iterations per hour.

# %run main.py
# Out:
# 1  Campbell
# 2  van Genuchten with m = 1-1/n restriction
# 3  Ippisch-van Genuchten
# Select water retention curve: 1
#
# 1  Cell-Centered Finite Volume
# 2  Matric Potential with Newton-Raphson
# 3  Matric Flux Potential with Newton-Raphson
# Select solver: 1
#
# Initial degree of saturation ]0-1]:0.25
#
# 1: Free drainage
# 2: Constant water potential
# Select lower boundary condition:1
#
# Nr of simulation hours:5
# dt = 360.0 No convergence
# dt = 180.0 No convergence
# dt = 90.0 No convergence
# dt = 45.0 No convergence
# dt = 22.5 No convergence
# dt = 11.25 No convergence
# nr of iterations per hour: 872.8

# %%
##Chapter_8.3

#Using:

    #initial water content of 0.25
    #Campbell water retention curve
    #cell-centered finite volume as a solver
    #constant water potential as the lower boundary condition

#there is no change in the cumulative infiltration and the number of iterations (i.e., 872.8/hr).

# %run main.py
# Out:
# 1  Campbell
# 2  van Genuchten with m = 1-1/n restriction
# 3  Ippisch-van Genuchten
# Select water retention curve: 1
#
# 1  Cell-Centered Finite Volume
# 2  Matric Potential with Newton-Raphson
# 3  Matric Flux Potential with Newton-Raphson
# Select solver: 1
#
# Initial degree of saturation ]0-1]:0.25
#
# 1: Free drainage
# 2: Constant water potential
# Select lower boundary condition:2
#
# Nr of simulation hours:5
# dt = 360.0 No convergence
# dt = 180.0 No convergence
# dt = 90.0 No convergence
# dt = 45.0 No convergence
# dt = 22.5 No convergence
# dt = 11.25 No convergence
# nr of iterations per hour: 872.8

# %%
##Chapter_8.4

#Infiltration in layered soil (top=sand, bottom=clay)

# %run main.py
# Out:
# File name: soil_sand_clay.txt
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-8/PSP_soil.py:59: RuntimeWarning: divide by zero encountered in scalar divide
#   horizon.VG_m =  1. - (1. / horizon.VG_n)
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-8/PSP_soil.py:62: RuntimeWarning: divide by zero encountered in scalar divide
#   horizon.VG_m_mod =  1. - (1. / horizon.VG_n_mod)
# 1  Campbell
# 2  van Genuchten with m = 1-1/n restriction
# 3  Ippisch-van Genuchten
# Select water retention curve: 1
#
# Initial degree of saturation ]0-1]:0.55
#
# 1: Free drainage
# 2: Constant water potential
# Select lower boundary condition:1
#
# Nr of simulation hours:5
# dt = 360.0 No convergence
# dt = 180.0 No convergence
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-8/PSP_soil.py:104: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# nr of iterations per hour: 255.0

# %%
##Chapter_8.5
