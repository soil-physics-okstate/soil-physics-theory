# %%
from google.colab import drive
drive.flush_and_unmount()
# Out:
# Drive not mounted, so nothing to flush and unmount.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github
# %cd 'soil-physics-theory'
# %cd 'content/Project'
# Out:
# /content/drive/MyDrive/Github
# /content/drive/MyDrive/Github/soil-physics-theory
# /content/drive/MyDrive/Github/soil-physics-theory/content/Project

# %%
import numpy as np
import matplotlib.pyplot as plt
thetar= (Winitial-Wfinal/Winitial)*100. #thetar=residual water content
thetas=total porosity
#Winitial=initial weight of sample before drying
#Wfinal=final weight of sample after drying
#At saturation point, saturated water content=total porosity

temperature_weekly = [20, 22, 25, 27, 23]  # Weekly temperature measurements (Celsius)
soil_moisture_weekly = [0.3, 0.28, 0.25, 0.22, 0.27]  # Corresponding weekly soil moisture measurements
matric_potential_weekly = [100, 80, 60, 40, 70]  # Corresponding weekly matric potential measurements (cm)

# Plot water retention curves for each temperature
plt.figure(figsize=(8, 6))
for temp, moisture, potential in zip(temperature_weekly, soil_moisture_weekly, matric_potential_weekly):
    plt.plot(potential, moisture, marker='o', label=f'Temperature: {temp}°C')
plt.xlabel('Matric Potential (cm)')
plt.ylabel('Soil Moisture')
plt.title('Water Retention Curve')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: source code string cannot contain null bytes
