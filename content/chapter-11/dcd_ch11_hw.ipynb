# %% [markdown]
# # 95% - inaccurate explanation #2

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
# %cd drive
# %cd MyDrive
# %cd GitHub
# %cd soil-physics-theory
# %cd content
# %cd chapter-11
# Out:
# /content/drive
# /content/drive/MyDrive
# /content/drive/MyDrive/GitHub
# /content/drive/MyDrive/GitHub/soil-physics-theory
# /content/drive/MyDrive/GitHub/soil-physics-theory/content
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-11

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **11.1)
# Simulate first- and second-stage evaporation with varying potential evaporation rates and soil texture. Plot the results. What effect does each of these have on the length of first-stage evaporation?**

# %%
import importlib
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_sand_50 = E
# %run main.py
E_silt_50 = E
# %run main.py
E_clay_50 = E
# Out:
# Potential evaporation (mm/h): .5
# Soil file name: sand.txt
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:25: RuntimeWarning: divide by zero encountered in scalar divide
#   c[i] /=  b[i]
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:26: RuntimeWarning: divide by zero encountered in scalar divide
#   d[i] /=  b[i]
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:27: RuntimeWarning: invalid value encountered in scalar multiply
#   b[i + 1] -=  a[i + 1] * c[i]
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:28: RuntimeWarning: invalid value encountered in scalar multiply
#   d[i + 1] -=  a[i + 1] * d[i]
# ...

# %%
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_sand_12 = E
# Out:
# Potential evaporation (mm/h): .12
# Soil file name: sand.txt
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# Cumulative evaporation (mm):  8.121

# %% [markdown]
# when holding the three soil textures to the same possible evaporation we can see that the silt loam had the most evap followed by the sand and then clay. Originally I had assumed sand would have the most but it stands to reason that the intense drop in hydraulic conductivity in the sand would have lead to less total evaporation. when lowering the potential evaporation we see that the stage one evap lasts much loger and has less totall evaporation all told.

# %% [markdown]
# **11.2)
# Plot cumulative evaporation for varying potential evaporation rates. What effect does rate have on cumulative evaporation?**

# %%
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_sand_30 = E
# Out:
# Potential evaporation (mm/h): .3
# Soil file name: sand.txt
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# Cumulative evaporation (mm):  10.800

# %%
plt.scatter(0.12,E_sand_12)
plt.scatter(0.30,E_sand_30)
plt.scatter(0.50,E_sand_50)
plt.xlabel('possible evap (mm/h)')
plt.ylabel('toatl evap (mm)')
plt.show()

# %% [markdown]
# the possible rate of evaportation and total evap have a positive relationship. as possible evap increases for one particular soil then the total evaporation increases.

# %% [markdown]
# **11.3)
# Compare moisture profiles for simulations with and without vapour flux in soil.
# Use a loam soil, starting at around 0.15m3 m–3 initial water content.**
