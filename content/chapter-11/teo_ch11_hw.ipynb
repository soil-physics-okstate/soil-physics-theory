# %%
from google.colab import drive
drive.flush_and_unmount()
# Out:
# Drive not mounted, so nothing to flush and unmount.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/MyDrive/Github/soil-physics-theory/content/chapter-11')

# %% [markdown]
# **11.1)
# Simulate first- and second-stage evaporation with varying potential evaporation rates and soil texture. Plot the results. What effect does each of these have on the length of first-stage evaporation?**

# %% [markdown]
# # Sand with high potential evaporation, 0.5 mm/h

# %%
import importlib
import PSP_soil
# Out:
# Potential evaporation (mm/h): 0.5

# %%
importlib.reload(PSP_soil)
# %run main.py
E_sand_05 = E
# Out:
# Potential evaporation (mm/h): 0.5
# Soil file name: sand.txt
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:25: RuntimeWarning: divide by zero encountered in scalar divide
#   c[i] /=  b[i]
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:26: RuntimeWarning: divide by zero encountered in scalar divide
#   d[i] /=  b[i]
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:27: RuntimeWarning: invalid value encountered in scalar multiply
# ...

# %% [markdown]
# # Sand with moderate potential evaporation rate, 0.25 mm/h

# %%
importlib.reload(PSP_soil)
# %run main.py
E_sand_025 = E
# Out:
# Potential evaporation (mm/h): 0.25
# Soil file name: sand.txt
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# Cumulative evaporation (mm):  10.344

# %% [markdown]
# # Sand with low potential evaporation rate, 0.12 mm/h

# %%
importlib.reload(PSP_soil)
# %run main.py
E_sand_012 = E
# Out:
# Potential evaporation (mm/h): 0.12
# Soil file name: sand.txt
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# Cumulative evaporation (mm):  8.121

# %% [markdown]
# # Silt loam with high potential evaporation rate, 0.5 mm/h

# %%
importlib.reload(PSP_soil)
# %run main.py
E_siltLoam_05 = E
# Out:
# Potential evaporation (mm/h): 0.5
# Soil file name: siltLoam.txt
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# Cumulative evaporation (mm):  13.247

# %% [markdown]
# **11.2)
# Plot cumulative evaporation for varying potential evaporation rates. What effect does rate have on cumulative evaporation?**

# %%
# prompt: plot cumulative evaporation for varying potential evaporation rates using main.py

# Plot cumulative evaporation for varying potential evaporation rates.
import matplotlib.pyplot as plt
plt.plot(0.5, E_sand_05,'ko')
plt.plot(0.25, E_sand_025,'ko')
plt.plot(0.12, E_sand_012,'ko')
plt.xlabel("Evaporation rate (mm/h)")
plt.ylabel("Cumulative Evaporation (mm)")
plt.title("Cumulative Evaporation vs Potential Evaporation Rates in Sand")
plt.show()

# %% [markdown]
# **11.3)
# Compare moisture profiles for simulations with and without vapour flux in soil.
# Use a loam soil, starting at around 0.15m3 m–3 initial water content.**

# %%
importlib.reload(PSP_soil)
# Out:
# Potential evaporation (mm/h): 0.25
# <module 'PSP_soil' from '/content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py'>

# %%
run main_no_vapor.py

# %%
E_no_vapor = E
theta_no_vapor = theta

# %%
importlib.reload(PSP_soil)
# Out:
# Potential evaporation (mm/h): 0.25
# <module 'PSP_soil' from '/content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py'>

# %%
run main.py
# Out:
# Soil file name: loam.txt
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py:66: RuntimeWarning: divide by zero encountered in scalar divide
#   soil.VG_m =  1. - (1. / soil.VG_n)
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py:69: RuntimeWarning: divide by zero encountered in scalar divide
#   soil.VG_m_mod =  1. - (1. / soil.VG_n_mod)
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# Cumulative evaporation (mm):  3.732

# %%
E_vapor = E
theta_vapor = theta

# %%
plt.plot(theta, -z, 'yo')
plt.plot(theta_no_vapor, -z, 'ro')

# %%
0].set_xlim(0, soil.thetaS)
            myPlot[0].set_xlabel("Water content [m$^3$ m$^{-3}$]",fontsize=16,labelpad=8)
            myPlot[0].set_ylabel("Depth [m]",fontsize=16,labelpad=8)

            myPlot[1].plot(time/3600., evaporationFlux*3600., 'ro')
              plt.show()

# %% [markdown]
# **11.4)
# Using the files clay.txt and sand.txt, compare the evaporative fluxes obtained for the two soils having different textures. The user may need to increase the simulation time to two or three days to observe the change from first-stage to second-stage evaporation.**
