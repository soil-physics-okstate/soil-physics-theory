# %% [markdown]
# # 90 % - #1 incomplete explanation, #2 missing

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/GitHub/
# %cd 'soil-physics-theory'
# %cd 'content/chapter-11'
import os

# %%
##Chapter_11.1

##Constant-rate stage of evaporation is longer for clay soil relative to sand and siltloam.
##For sand @ 0.35 mm/h evaporation rate

import importlib
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_sand_35 = E
# Out:
# Potential evaporation (mm/h): 0.35
# Potential evaporation (mm/h): 0.35
# Soil file name: sand.txt
# /content/drive/MyDrive/GitHub/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# Cumulative evaporation (mm):  11.165

# %%
##For Silt loam @ 0.35 mm/h evaporation rate

import importlib
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_siltloam_35 = E
# Out:
# Potential evaporation (mm/h): 0.35
# Soil file name: siltLoam.txt
# Cumulative evaporation (mm):  13.103

# %%
##For Clay @ 0.35 mm/h evaporation rate

import importlib
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_clay_35 = E
# Out:
# Potential evaporation (mm/h): 0.35
# Soil file name: clay.txt
# Cumulative evaporation (mm):  9.007

# %%
##Chapter_11.2

##Reducing the potential evaporation rate (from 0.35 to 0.15 m/h) makes the constant-rate stage of evaporation longer for all soil texture
##For Sand @ 0.15 mm/h evaporation rate

import importlib
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_sand_15 = E
# Out:
# Potential evaporation (mm/h): 0.15
# Soil file name: sand.txt
# Cumulative evaporation (mm):  8.871

# %%
##For Silt loam @ 0.15 mm/h evaporation rate

import importlib
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_siltloam_15 = E
# Out:
# Potential evaporation (mm/h): 0.15
# Soil file name: siltLoam.txt
# Cumulative evaporation (mm):  11.539

# %%
##For Clay @ 0.15 mm/h evaporation rate

import importlib
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_clay_15 = E
# Out:
# Potential evaporation (mm/h): 0.15
# Soil file name: clay.txt
# Cumulative evaporation (mm):  8.607
