# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# %cd /content/drive/MyDrive/Github/
# %cd 'soil-physics-theory'
# %cd 'content/chapter-11'
# Out:
# /content/drive/MyDrive/Github
# /content/drive/MyDrive/Github/soil-physics-theory
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11

# %%
import os

# %% [markdown]
# **11.1. Simulate first- and second-stage evaporation with varying potential evaporation rates and soil texture. Plot the results. What effect does each of these have on the length of first-stage evaporation?**

# %%
#Sand with high potential evaporation, 0.5 mm/h
#Sand with potential evaporation, 0.4 mm/h (assume)
import importlib
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_sand_04 = E
# Out:
# Potential evaporation (mm/h): 0.4
# Soil file name: sand.txt
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# Cumulative evaporation (mm):  8.943

# %%
import importlib
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_siltloam_04 = E
# Out:
# Potential evaporation (mm/h): 0.4
# Soil file name: siltLoam.txt
# Cumulative evaporation (mm):  3.700

# %%
import importlib
import PSP_soil
importlib.reload(PSP_soil)
# %run main.py
E_sand_06 = E
# Out:
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_soil.py:96: RuntimeWarning: divide by zero encountered in scalar power
#   psi = soil.Campbell_he * Se**(-soil.Campbell_b)
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:25: RuntimeWarning: divide by zero encountered in scalar divide
#   c[i] /=  b[i]
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:26: RuntimeWarning: divide by zero encountered in scalar divide
#   d[i] /=  b[i]
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:27: RuntimeWarning: invalid value encountered in scalar multiply
#   b[i + 1] -=  a[i + 1] * c[i]
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:28: RuntimeWarning: invalid value encountered in scalar multiply
#   d[i + 1] -=  a[i + 1] * d[i]
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:25: RuntimeWarning: overflow encountered in scalar divide
#   c[i] /=  b[i]
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/PSP_ThomasAlgorithm.py:26: RuntimeWarning: overflow encountered in scalar divide
#   d[i] /=  b[i]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/main.py in <module>
#      72     return sumEvaporation, vap.theta, vap.z
#      73
# ---> 74 E, theta, z = main()
#      75 print("Cumulative evaporation (mm): ", format(E, '.3f'))
#
# /content/drive/MyDrive/Github/soil-physics-theory/content/chapter-11/main.py in main()
#      48             #      "\tsumEvap:", format(sumEvaporation, '.3f'))
#      49
# ---> 50             myPlot[0].clear()
#      51             myPlot[0].set_xlim(0, soil.thetaS)
#      52             myPlot[0].set_xlabel("Water content [m$^3$ m$^{-3}$]",fontsize=16,labelpad=8)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in clear(self)
#    1393             self.cla()
#    1394         else:
# -> 1395             self.__clear()
#    1396
#    1397     def cla(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __clear(self)
#    1279             axis.clear()  # Also resets the scale to linear.
#    1280         for spine in self.spines.values():
# -> 1281             spine.clear()
#    1282
#    1283         self.ignore_existing_data_limits = True
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/spines.py in clear(self)
#     223         self._position = None  # clear position
#     224         if self.axis is not None:
# --> 225             self.axis.clear()
#     226
#     227     def _adjust_location(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in clear(self)
#     875         self.labelpad = mpl.rcParams['axes.labelpad']
#     876
# --> 877         self._init()
#     878
#     879         self._set_scale('linear')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _init(self)
#    2501         # x in display coords, y in axes coords (to be updated at draw time by
#    2502         # _update_label_positions and _update_offset_text_position).
# -> 2503         self.label.set(
#    2504             x=0, y=0.5,
#    2505             verticalalignment='bottom', horizontalalignment='center',
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     145             return
#     146
# --> 147         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148         cls.set.__name__ = "set"
#     149         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in set(self, **kwargs)
#    1229         # Artist._update_set_signature_and_docstring() at the end of the
#    1230         # module.
# -> 1231         return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#    1232
#    1233     @contextlib.contextmanager
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1221         The lack of prenormalization is to maintain backcompatibility.
#    1222         """
# -> 1223         return self._update_props(
#    1224             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225             "{prop_name!r}")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1186         """
#    1187         ret = []
# -> 1188         with cbook._setattr_cm(self, eventson=False):
#    1189             for k, v in props.items():
#    1190                 # Allow attributes we want to be able to update through
#
# /usr/lib/python3.10/contextlib.py in __enter__(self)
#     133         del self.args, self.kwds, self.func
#     134         try:
# --> 135             return next(self.gen)
#     136         except StopIteration:
#     137             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py in _setattr_cm(obj, **kwargs)
#    2004             # if we are pulling from the instance dict or the object
#    2005             # does not have this attribute we can trust the above
# -> 2006             origs[attr] = orig
#    2007         else:
#    2008             # if the attribute is not in the instance dict it must be
#
# KeyboardInterrupt:

# %% [markdown]
# **11.2. Plot cumulative evaporation for varying potential evaporation rates. What effect does rate have on cumulative evaporation?**

# %%
# prompt: plot cumulative evaporation for varying potential evaporation rates using main.py

# Plot cumulative evaporation for varying potential evaporation rates.
import matplotlib.pyplot as plt
E_sand_06=E
E_sand_45=E
E_sand_30=E
E_sand_15=E
plt.plot(0.6, E_sand_06,'ro')
plt.plot(0.45, E_sand_45,'ko')
plt.plot(0.30, E_sand_30,'r*')
plt.plot(0.15, E_sand_15,'bo')
plt.xlabel("Evaporation rate (mm/h)")
plt.ylabel("Cumulative Evaporation (mm)")
plt.title("Cumulative Evaporation vs Potential Evaporation Rates in Sand")
plt.show()

# %% [markdown]
# **11.3. Compare moisture profiles for simulations with and without vapour flux in soil. Use a loam soil, starting at around 0.15 m3 m–3 initial water content.**

# %% [markdown]
# **11.4. Using the files clay.txt and sand.txt, compare the evaporative fluxes ob- tained for the two soils having different textures. The user may need to increase the simulation time to two or three days to observe the change from first-stage to second-stage evaporation.**
